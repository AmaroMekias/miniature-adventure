# %%
idade = 18
if idade >= 18:
  print("Você é mais de idade.")
  print("Pode entrar na festa!")
print("Fim da festa")
# Out:
# Você é mais de idade.
# Pode entrar na festa!
# Fim da festa

# %%
nota= 6
if nota >= 7:
  print("Aprovado")
else:
  print("Reprovado")
# Out:
# Reprovado

# %%
cor = input("Digite a cor do semáforo(verde/amarelo/vermelho): ").lower()

if cor == "verde"
  print("siga em mfrente!")
elif cor == "amarelo":
  print("Atenção!, diminua a velocidade.")
elif cor == "vermelho":
  print("Pare!")
  else:
    print("cor invalida")
# Out:
# Digite a cor do semáforo(verde/amarelo/vermelho): okijgi
# cor invalida

# %%
numero = int(input("Digite  um número inteiro: "))

if (numero == 0)
  print(Zero)
elif (umero > 0):
  print("Positivo")
else (numero < 0):
  print("Negativo")
# Out:
# Digite  um número inteiro: 2
# Positivo
