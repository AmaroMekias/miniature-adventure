# %% [markdown]
# <a href="https://colab.research.google.com/github/AmaroMekias/miniature-adventure/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
peso = float(input("Digite seu peso em KG: "))
altura = float(input("Digite sua altura em Metros: "))

imc = peso / (altura ** 2)

print(f"Seu Índice de Massa Corporal (IMC) é: {imc:.2f}")
# Out:
# Digite seu peso em KG: 61
# Digite sua altura em Metros: 1.64
# Seu Índice de Massa Corporal (IMC) é: 22.68
